# %% [markdown]
# # **Computational Drug Discovery [Part 1] Download Bioactivity Data**

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
import sys
# !{sys.executable} -m pip install chembl_webresource_client
import sys
# !{sys.executable} -m pip install pandas

# pip install chembl_webresource_client  --> doesn't work because it's not explicit enough about where the package will be installed. 
# same for importing pandas
# Out:
# ...
# WARNING: You are using pip version 21.1.1; however, version 21.2.4 is available.
# You should consider upgrading via the 'C:\Users\kelly\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 21.1.1; however, version 21.2.4 is available.
# You should consider upgrading via the 'C:\Users\kelly\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.
# ...

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for coronavirus**

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('coronavirus')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references  \
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  [{'xref_id': 'P0C6U8', 'xref_name': None, 'xre...
# 5                                                 []
# 6  [{'xref_id': 'P0C6X7', 'xref_name': None, 'xre...
# 7                                                 []
#
#                                             organism  \
# 0                                        Coronavirus
# 1                                   SARS coronavirus
# 2                                 Feline coronavirus
# 3                             Human coronavirus 229E
# 4                                   SARS coronavirus
# 5  Middle East respiratory syndrome-related coron...
# 6                                   SARS coronavirus
# 7    Severe acute respiratory syndrome coronavirus 2
#
# ...

# %% [markdown]
# ### **Select and retrieve bioactivity data for *SARS coronavirus 3C-like proteinase* (fifth entry)**

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein, *coronavirus 3C-like proteinase*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[4]
selected_target
# Out:
# 'CHEMBL3927'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *coronavirus 3C-like proteinase* (CHEMBL3927) that are reported as IC$_{50}$ values in nM (nanomolar) unit.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df.head(3)
# Out:
#   activity_comment  activity_id activity_properties assay_chembl_id  \
# 0             None      1480935                  []    CHEMBL829584
# 1             None      1480936                  []    CHEMBL829584
# 2             None      1481061                  []    CHEMBL830868
#
#                                    assay_description assay_type  \
# 0  In vitro inhibitory concentration against SARS...          B
# 1  In vitro inhibitory concentration against SARS...          B
# 2  In vitro inhibitory concentration against SARS...          B
#
#   assay_variant_accession assay_variant_mutation bao_endpoint   bao_format  \
# 0                    None                   None  BAO_0000190  BAO_0000357
# 1                    None                   None  BAO_0000190  BAO_0000357
# 2                    None                   None  BAO_0000190  BAO_0000357
#
#    ...   target_organism                     target_pref_name target_tax_id  \
# ...

# %%
df.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('C:/Users/kelly/Desktop/coronavirus_3C-like_proteinase_bioactivity_data.csv', index=False)

# template: 
# df.to_csv(r'Path where you want to store the exported CSV file\File Name.csv')
# in this case: df.to_csv('C:/Users/xxxx/Desktop/coronavirus_3C-like_proteinase_bioactivity_data.csv')

# %% [markdown]
# Taking a glimpse of the **bioactivity_data.csv** file that we've just created.

# %%
csv_file = pd.read_csv('C:/Users/kelly/Desktop/coronavirus_3C-like_proteinase_bioactivity_data.csv')
csv_file

# template: 
# pd.read_csv(r'Path where you want to store the exported CSV file\File Name.csv')
# in this case: pd.read_csv('C:/Users/xxxx/Desktop/coronavirus_3C-like_proteinase_bioactivity_data.csv')
# Out:
#      activity_comment  activity_id activity_properties assay_chembl_id  \
# 0                 NaN      1480935                  []    CHEMBL829584
# 1                 NaN      1480936                  []    CHEMBL829584
# 2                 NaN      1481061                  []    CHEMBL830868
# 3                 NaN      1481065                  []    CHEMBL829584
# 4                 NaN      1481066                  []    CHEMBL829584
# ..                ...          ...                 ...             ...
# 128               NaN     12041507                  []   CHEMBL2150313
# 129               NaN     12041508                  []   CHEMBL2150313
# 130               NaN     12041509                  []   CHEMBL2150313
# 131               NaN     12041510                  []   CHEMBL2150313
# 132               NaN     12041511                  []   CHEMBL2150313
#
#                                      assay_description assay_type  \
# ...

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** column then drop it

# %%
df2 = df[df.standard_value.notna()]
df2

# Apparently, for this dataset there is no missing data. But we can use the above code cell for bioactivity data of other target protein.
# Out:
#     activity_comment  activity_id activity_properties assay_chembl_id  \
# 0               None      1480935                  []    CHEMBL829584
# 1               None      1480936                  []    CHEMBL829584
# 2               None      1481061                  []    CHEMBL830868
# 3               None      1481065                  []    CHEMBL829584
# 4               None      1481066                  []    CHEMBL829584
# ..               ...          ...                 ...             ...
# 128             None     12041507                  []   CHEMBL2150313
# 129             None     12041508                  []   CHEMBL2150313
# 130             None     12041509                  []   CHEMBL2150313
# 131             None     12041510                  []   CHEMBL2150313
# 132             None     12041511                  []   CHEMBL2150313
#
#                                      assay_description assay_type  \
# ...

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
bioactivity_class = []
for i in df2.standard_value:
  if float(i) >= 10000:
    bioactivity_class.append("inactive")
  elif float(i) <= 1000:
    bioactivity_class.append("active")
  else:
    bioactivity_class.append("intermediate")

# %% [markdown]
# ### **Iterate the *molecule_chembl_id* to a list**

# %%
mol_cid = []
for i in df2.molecule_chembl_id:
  mol_cid.append(i)

print(mol_cid[:10])
# Out:
# ['CHEMBL187579', 'CHEMBL188487', 'CHEMBL185698', 'CHEMBL426082', 'CHEMBL187717', 'CHEMBL365134', 'CHEMBL187598', 'CHEMBL190743', 'CHEMBL365469', 'CHEMBL188983']

# %% [markdown]
# ### **Iterate *canonical_smiles* to a list**

# %%
canonical_smiles = []
for i in df2.canonical_smiles:
  canonical_smiles.append(i)

print(canonical_smiles[:10])
# Out:
# ['Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21', 'O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21', 'O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21', 'O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21', 'O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]', 'O=C1C(=O)N(Cc2cc3ccccc3s2)c2c(Br)cccc21', 'O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccc(F)cc21', 'O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccc(I)cc21', 'O=C1C(=O)N(Cc2cc3ccccc3s2)c2cccc(Cl)c21', 'O=C1C(=O)N(C/C=C/c2cc3ccccc3s2)c2ccc(I)cc21']

# %% [markdown]
# ### **Iterate *standard_value* to a list**

# %%
standard_value = []
for i in df2.standard_value:
  standard_value.append(i)

print(standard_value[:10])
# Out:
# ['7200.0', '9400.0', '13500.0', '13110.0', '2000.0', '980.0', '4820.0', '950.0', '11200.0', '23500.0']

# %% [markdown]
# ### **Combine the 4 lists into a dataframe**

# %%
data_tuples = list(zip(mol_cid, canonical_smiles, bioactivity_class, standard_value))
df3 = pd.DataFrame( data_tuples,  columns=['molecule_chembl_id', 'canonical_smiles', 'bioactivity_class', 'standard_value'])

# %%
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL187579             Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21
# 1         CHEMBL188487             O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21
# 2         CHEMBL185698            O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 3         CHEMBL426082                O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21
# 4         CHEMBL187717    O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]
# ..                 ...                                                ...
# 128      CHEMBL2146517  COC(=O)[C@@]1(C)CCCc2c1ccc1c2C(=O)C(=O)c2c(C)c...
# 129       CHEMBL187460        C[C@H]1COC2=C1C(=O)C(=O)c1c2ccc2c1CCCC2(C)C
# 130       CHEMBL363535             Cc1coc2c1C(=O)C(=O)c1c-2ccc2c(C)cccc12
# 131       CHEMBL227075      Cc1cccc2c3c(ccc12)C1=C(C(=O)C3=O)[C@@H](C)CO1
# 132        CHEMBL45830             CC(C)C1=Cc2ccc3c(c2C(=O)C1=O)CCCC3(C)C
#
#     bioactivity_class standard_value
# 0        intermediate         7200.0
# ...

# %% [markdown]
# ## **Save dataframe to CSV file**

# %%
df3.to_csv('C:/Users/kelly/Desktop/bioactivity_preprocessed_data.csv', index=False)

# template: 
# df3.to_csv(r'Path where you want to store the exported CSV file\File Name.csv')
# in this case: df3.to_csv('C:/Users/xxxx/Desktop/bioactivity_preprocessed_data.csv')

# %%
csv_file2 = pd.read_csv('C:/Users/kelly/Desktop/bioactivity_preprocessed_data.csv')
csv_file2

# template: 
# pd.read_csv(r'Path where you want to store the exported CSV file\File Name.csv')
# in this case: pd.read_csv('C:/Users/xxxx/Desktop/bioactivity_preprocessed_data.csv')
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0         CHEMBL187579             Cc1noc(C)c1CN1C(=O)C(=O)c2cc(C#N)ccc21
# 1         CHEMBL188487             O=C1C(=O)N(Cc2ccc(F)cc2Cl)c2ccc(I)cc21
# 2         CHEMBL185698            O=C1C(=O)N(CC2COc3ccccc3O2)c2ccc(I)cc21
# 3         CHEMBL426082                O=C1C(=O)N(Cc2cc3ccccc3s2)c2ccccc21
# 4         CHEMBL187717    O=C1C(=O)N(Cc2cc3ccccc3s2)c2c1cccc2[N+](=O)[O-]
# ..                 ...                                                ...
# 128      CHEMBL2146517  COC(=O)[C@@]1(C)CCCc2c1ccc1c2C(=O)C(=O)c2c(C)c...
# 129       CHEMBL187460        C[C@H]1COC2=C1C(=O)C(=O)c1c2ccc2c1CCCC2(C)C
# 130       CHEMBL363535             Cc1coc2c1C(=O)C(=O)c1c-2ccc2c(C)cccc12
# 131       CHEMBL227075      Cc1cccc2c3c(ccc12)C1=C(C(=O)C3=O)[C@@H](C)CO1
# 132        CHEMBL45830             CC(C)C1=Cc2ccc3c(c2C(=O)C1=O)CCCC3(C)C
#
#     bioactivity_class  standard_value
# 0        intermediate          7200.0
# ...

# %% [markdown]
# ---
